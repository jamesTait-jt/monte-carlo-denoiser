# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p1 = 3
p2 = 2
p3 = 1
p4 = 4

q1 = 1
q2 = 2
q3 = 4
q4 = 3

# %%
def plotgrid(fig, ax):
    for row in ax:
        for col in row:
            for x in range(1, 5):
                col.axvline(x=x, linestyle="dotted", color="grey")
                col.axhline(y=x, linestyle="dotted", color="grey")

# %%
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(13, 5))
fig.tight_layout()

bars = ax[0][0].bar([1, 2, 3, 4]   , [3, 2, 1, 4]   , color="b")
bars = ax[0][1].bar([1, 2, 2, 3, 4], [1, 4, 2, 1, 4], color="b")
bars[1].set_color("g")
bars = ax[0][2].bar([1, 2, 3, 3, 4], [1, 2, 3, 1, 4], color="b")
bars[2].set_color("g")
bars = ax[0][3].bar([1, 2, 3, 4]   , [1, 2, 3, 4]   , color="b")

bars = ax[1][0].bar([1, 2, 3, 4]   , [1, 2, 4, 3], color="r")
bars = ax[1][1].bar([1, 2, 3, 4]   , [1, 2, 4, 3], color="r")
bars = ax[1][2].bar([1, 2, 3, 4]   , [1, 2, 4, 3], color="r")
bars = ax[1][3].bar([1, 2, 3, 4, 4], [1, 2, 3, 4, 3], color="r")
bars[3].set_color("g")

ax[0][0].set_ylabel("Shovelfulls in pile")
ax[1][0].set_ylabel("Shovelfulls in pile")

xs = [1, 2, 3, 4]
ps = ["bop", "$p_1$", "$p_2$", "$p_3$", "$p_4$"]
qs = ["bop", "$q_1$", "$q_2$", "$q_3$", "$q_4$"]

for i in range(4):
    ax[0][i].set_xticklabels(ps)
    ax[1][i].set_xticklabels(qs)


plotgrid(fig, ax)

plt.savefig("img/emd.png")
